# %% [markdown]
# Сначала всё подключим: mystem, pymorphy, nltk, json. И возьмём текст (и его кусочек для экспериментов)

# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.tokenize import RegexpTokenizer
from pymorphy2 import MorphAnalyzer
from pymystem3 import Mystem
import os

os.environ["MYSTEM_BIN"] = "C:\\mystem.exe"
ms = Mystem()

morph = MorphAnalyzer()

tokenizer = RegexpTokenizer(r'\w+')

with open('book.txt', 'r', encoding='utf-8') as f:
    text = f.read()
with open('book.txt', 'r', encoding='utf-8') as f:
    text_lines = f.readlines()

with open('book_part.txt', 'r', encoding='utf-8') as f:
    text_short = f.read()
with open('book_part.txt', 'r', encoding='utf-8') as f:
    text_short_lines = f.readlines()

# %% [markdown]
# Вот в этой клеточке замерим время работы майстема

# %%
# %%time

lemmas = ms.lemmatize(text_short)
# Out:
# Wall time: 4min 23s

# %% [markdown]
# А вот в этой нлтк+пайморфи

# %%
# %%time

tokens = word_tokenize(text_short)
analyze = []
for token in tokens:
    analyze.append(morph.parse(token)[0])
# Out:
# Wall time: 848 ms

# %% [markdown]
# На windows модуль mystem работает ооочень медленно, в отличие от pymorphy.

# %% [markdown]
# Сделаем json с леммами

# %%
lemmas = []
for line in text_lines:
    # не берём последний элемент списка, потому что это '\n'
    lemmas.extend(ms.lemmatize(line)[:-1])

with open('lemmas_mystem.json', 'w', encoding='utf-8') as file:
    json.dump(lemmas, file, ensure_ascii=False)

# %% [markdown]
# Теперь посмотрим на пайморфи и нлтк.

# %%
tokens = word_tokenize(text)
# нужный вид - {"lemma": "конь", "word": "коня", "pos": "NOUN"}
with open('pymorphy_analyze.jsonl', 'w', encoding='utf-8') as f:
    for token in tokens:
        analyze = morph.parse(token)[0]
        analyze_dict = {}
        analyze_dict['lemma'] = analyze.normal_form
        analyze_dict['word'] = token
        analyze_dict['pos'] = analyze.tag.POS
        f.write(json.dumps(analyze_dict, ensure_ascii=False)+'\n')

# %% [markdown]
# Вычислим частотность частей речи

# %%
freq = {}
# счётчик слов без части речи, чтобы отфильтровать знаки препинания, в основном
waste = 0
for token in tokens:
    pos_tag = morph.parse(token)[0].tag.POS
    if pos_tag in freq:
        freq[pos_tag] += 1
    elif pos_tag is not None:
        freq[pos_tag] = 1
    else:
        waste += 1
for pos in freq:
    freq[pos] = freq[pos]/(len(tokens) - waste)
for key in sorted(freq, key=freq.get, reverse=True):
    print(key, freq[key])
# Out:
# NOUN 0.23692669331932437
# VERB 0.17151786588786294
# CONJ 0.10103375508641338
# PREP 0.09857624945462964
# ADJF 0.09068730021636734
# NPRO 0.08327026329145483
# ADVB 0.07747375544257361
# PRCL 0.06899714181410216
# ADJS 0.021939470567808456
# INFN 0.020835373834688226
# PRED 0.006348556215441327
# PRTF 0.00595677995530189
# NUMR 0.004674603103936461
# COMP 0.004478714973866742
# GRND 0.0035437943530794505
# INTJ 0.0023239455430998407
# PRTS 0.0014157369400493282

# %% [markdown]
# Чаще всего встречаются существительные и глаголы, также частотны разные служебные части речи
# Теперь найдём самые частотные глаголы и наречия

# %%
import collections
verbs = []
adverbs = []
for token in tokens:
    analyze = morph.parse(token)[0]
    pos_tag = analyze.tag.POS
    if pos_tag == 'VERB':
        verbs.append(analyze.normal_form)
    if pos_tag == 'ADVB':
        adverbs.append(analyze.normal_form)

counter_verb = collections.Counter(verbs)
counter_advb = collections.Counter(adverbs)
print(counter_verb)
print(counter_advb)
# Out:
# Counter({'быть': 1391, 'сказать': 1154, 'мочь': 457, 'знать': 410, 'спросить': 303, 'стать': 243, 'говорить': 228, 'хотеть': 193, 'подумать': 166, 'смотреть': 157, 'пойти': 152, 'идти': 150, 'стоять': 143, 'бояться': 121, 'думать': 118, 'посмотреть': 104, 'казаться': 103, 'взять': 98, 'увидеть': 93, 'оказаться': 90, 'сидеть': 89, 'уйти': 89, 'понять': 88, 'вздохнуть': 84, 'отозваться': 84, 'давать': 80, 'жить': 79, 'объяснить': 77, 'сделать': 76, 'улыбнуться': 76, 'проговорить': 76, 'видеть': 71, 'понимать': 69, 'прийти': 69, 'остаться': 66, 'сесть': 64, 'играть': 63, 'помнить': 62, 'заметить': 57, 'дать': 55, 'лежать': 54, 'успеть': 54, 'вспомнить': 52, 'ответить': 52, 'оглянуться': 52, 'молчать': 52, 'поднять': 51, 'усмехнуться': 51, 'бывать': 51, 'послать': 50, 'вернуться': 50, 'появиться': 49, 'ждать': 48, 'решить': 48, 'начать': 47, 'верить': 47, 'делать': 46, 'получиться': 46, 'случиться': 45, 'найти': 45, 'прошептать': 45, 'встать': 45, 'кивнуть': 43, 'удивиться': 43, 'любить': 42, 'положить': 42, 'глянуть': 41, 'шагнуть': 41, 'хотеться': 41, 'уметь': 40, 'выйти': 39, 'стоить': 39, 'принести': 39, 'пройти': 39, 'засмеяться': 38, 'подойти': 38, 'гореть': 38, 'иметь': 38, 'уходить': 37, 'узнать': 35, 'показаться': 35, 'остановиться': 35, 'крикнуть': 35, 'висеть': 35, 'ходить': 35, 'смочь': 35, 'рассказать': 35, 'подняться': 34, 'попросить': 34, 'перестать': 33, 'звать': 33, 'слышать': 33, 'хватить': 32, 'согласиться': 32, 'возразить': 31, 'поставить': 30, 'держать': 30, 'испугаться': 30, 'прыгнуть': 29, 'побежать': 29, 'рассказывать': 29, 'бросить': 28, 'сделаться': 28, 'мыть': 28, 'блестеть': 27, 'оставить': 27, 'слушать': 26, 'показать': 26, 'бежать': 26, 'спрашивать': 26, 'снять': 25, 'кончиться': 25, 'погибнуть': 25, 'работать': 24, 'прийтись': 24, 'опустить': 24, 'забыть': 24, 'приходить': 24, 'услышать': 23, 'торчать': 23, 'писать': 23, 'чувствовать': 23, 'достать': 22, 'простить': 22, 'ехать': 22, 'замереть': 22, 'пробормотать': 22, 'дёрнуть': 22, 'велеть': 22, 'уехать': 22, 'упасть': 22, 'нравиться': 22, 'оставаться': 21, 'подождать': 21, 'исчезнуть': 21, 'выходить': 21, 'обрадоваться': 21, 'читать': 21, 'попасть': 21, 'пожать': 21, 'двинуться': 21, 'подарить': 21, 'садиться': 21, 'написать': 21, 'брать': 20, 'взяться': 20, 'вскочить': 20, 'отойти': 20, 'пахнуть': 20, 'сообщить': 20, 'хмыкнуть': 20, 'произнести': 20, 'светиться': 20, 'вытащить': 19, 'взглянуть': 19, 'вскинуть': 19, 'называться': 19, 'помолчать': 19, 'собираться': 19, 'ударить': 19, 
, 'бесполезно': 6, 'действительно': 6, 'разом': 6, 'обиженно': 5, 'неторопливо': 5, 'насквозь': 5, 'сокращённо': 5, 'впервые': 5, 'вопросительно': 5, 'ничуть': 5, 'строго': 5, 'плавно': 5, 'далее': 5, 'аккуратно': 5, 'лениво': 5, 'высоко': 5, 'бодро': 5, 'вполголоса': 5, 'беспокойно': 5, 'охотно': 5, 'прекрасно': 5, 'далеко-далеко': 5, 'ран ...

# %% [markdown]
# Никаких "особенных" глаголов в первой двадцатке не заметно, но можно заметить небольшое влияние приключенческого жанра ("сказать", "бояться", "взять"). Аналогично и в наречиях, много разных наречий для описания действия, которых в таком жанре много ("тут", "тогда", "здесь", "сейчас").

# %%
ngram_list = []
for line in text_lines[:1000]:
    line_tokens = tokenizer.tokenize(line)
    n_grams = list(ngrams(line_tokens, 2))
    ngram_list.extend(n_grams)
print(collections.Counter(ngram_list))
# Out:
# Counter({('сказала', 'Данка'): 16, ('сказал', 'Яр'): 13, ('не', 'было'): 10, ('сказал', 'Алька'): 10, ('Ну', 'и'): 9, ('и', 'что'): 8, ('посмотрел', 'на'): 7, ('спросил', 'Яр'): 7, ('к', 'Яру'): 6, ('кто', 'то'): 5, ('я', 'не'): 5, ('Ну', 'что'): 5, ('его', 'за'): 5, ('Это', 'был'): 5, ('все', 'же'): 5, ('Данка', 'и'): 5, ('сказал', 'Чита'): 5, ('он', 'не'): 5, ('что', 'он'): 5, ('Алька', 'и'): 5, ('и', 'Чита'): 4, ('что', 'не'): 4, ('подумал', 'Яр'): 4, ('Это', 'не'): 4, ('то', 'не'): 4, ('что', 'ли'): 4, ('какой', 'то'): 4, ('что', 'то'): 4, ('А', 'что'): 4, ('там', 'в'): 4, ('в', 'воду'): 4, ('хотя', 'бы'): 4, ('Но', 'тут'): 4, ('тут', 'же'): 4, ('Яр', 'Я'): 4, ('и', 'не'): 4, ('Яра', 'за'): 4, ('шагнул', 'к'): 4, ('сказал', 'он'): 4, ('У', 'нас'): 4, ('у', 'него'): 4, ('как', 'это'): 4, ('сказал', 'Игнатик'): 4, ('Игнатик', 'и'): 4, ('похожий', 'на'): 3, ('Яр', 'вспомнил'): 3, ('вспомнил', 'как'): 3, ('Кто', 'то'): 3, ('Раз', 'два'): 3, ('не', 'очень'): 3, ('и', 'так'): 3, ('Когда', 'он'): 3, ('он', 'был'): 3, ('взялся', 'за'): 3, ('Данка', 'А'): 3, ('А', 'почему'): 3, ('Яр', 'увидел'): 3, ('это', 'да'): 3, ('вы', 'не'): 3, ('на', 'песок'): 3, ('что', 'за'): 3, ('был', 'старый'): 3, ('у', 'Данки'): 3, ('Яр', 'Но'): 3, ('возразила', 'Данка'): 3, ('и', 'Тик'): 3, ('Яр', 'и'): 3, ('Яр', 'улыбнулся'): 3, ('у', 'нас'): 3, ('Яр', 'не'): 3, ('может', 'быть'): 3, ('что', 'это'): 3, ('А', 'если'): 3, ('в', 'субпространстве'): 3, ('крайней', 'мере'): 3, ('просто', 'не'): 3, ('Ну', 'а'): 3, ('что', 'же'): 3, ('ничего', 'не'): 3, ('это', 'было'): 3, ('ноль', 'ноль'): 3, ('Когда', 'Яр'): 3, ('не', 'знал'): 3, ('и', 'опять'): 3, ('где', 'он'): 3, ('он', 'и'): 3, ('Но', 'это'): 3, ('это', 'не'): 3, ('все', 'что'): 3, ('как', 'бы'): 3, ('понял', 'что'): 3, ('почти', 'не'): 3, ('на', 'Яра'): 3, ('Я', 'не'): 3, ('все', 'таки'): 3, ('Яру', 'в'): 3, ('не', 'совсем'): 3, ('потому', 'что'): 3, ('самом', 'деле'): 3, ('на', 'ты'): 3, ('Игнатика', 'и'): 3, ('И', 'все'): 3, ('то', 'что'): 3, ('за', 'руку'): 3, ('у', 'вас'): 3, ('к', 'Игнатику'): 3, ('такой', 'же'): 3, ('в', 'лицо'): 3, ('А', 'откуда'): 3, ('на', 'него'): 3, ('удивилась', 'Данка'): 3, ('дотянулся', 'до'): 2, ('сунул', 'в'): 2, ('Тик', 'посмотрел'): 2, ('и', 'сделал'): 2, ('от', 'книги'): 2, ('в', 'язык'): 2, ('и', 'тоже'): 2, ('Яр', 'осторожно'): 2, ('закрыл', 'глаза'): 2, ('и', 'я'): 2, ('в', 'цирк'): 2, ('два', 'три'): 2, ('как', 'он'): 2, ('та', 'та'): 2, ('тоже', 'не'): 2, ('на', 'спинку'): 2, ('спинку', 'скамьи'): 2, ('на', 'ней'): 2, ('Хотя', 'бы'): 2, ('Чита', 'поднял'): 2, ('поднял', 'голову'): 2, ('голову', 'и'): 2, ('в', 'его'): 2, ('в', 'траву'): 2, ('Вот', 'это'): 2, ('какого', 'то'): 2, ('и', 'все'): 2, ('Яру', 'Яр'): 2, ('за', 'плечо'): 2, ('и', 'разглядывал'): 2, ('на', 'ладонь'): 2, ('разу', 'не'): 2, ('Яр', 'у'): 2, ('по', 'вечерам'): 2, ('осторожно', 'сказал'): 2, ('посреди', 'поляны'): 2, ('в', 'этом'): 2, ('за', 'ним'): 2, ('то', 'пускай'): 2, ('Вода', 'была'): 2, ('и', 'теплая'): 2, ('Даже', 'Данка'): 2, ('объяснила', 'Данка'): 2, ('хотел', 'спросить'): 2, ('спросил', 'Тик'): 2, ('по', 'краям'): 2, ('похожая', 'на'): 2, ('на', 'другой'): 2, ('Яр', 'с'): 2, ('на', 'себя'): 2, ('не', 'так'): 2, ('улыбнулся', 'Яр'): 2, ('с', 'тобой'): 2, ('запрыгал', 'на'): 2, ('у', 'тебя'): 2, ('усмехнулся', 'Чита'): 2, ('Я', 'то'): 2, ('сказал', 'Тик'): 2, ('надел', 'очки'): 2, ('Но', 'все'): 2, ('же', 'на'): 2, ('по', 'всему'): 2, ('от', 'Яра'): 2, ('глаза', 'и'): 2, ('с', 'чуть'): 2, ('взглянул', 'на'): 2, ('из', 'кармана'): 2, ('Я', 'с'): 2, ('с', 'вами'): 2, ('Но', 'он'): 2, ('и', 'стал'): 2, ('Что', 'Алька'): 2, ('что', 'ты'): 2, ('Яр', 'сказал'): 2, ('подхватил', 'его'): 2, ('Алька', 'радостно'): 2, ('ногами', 'и'): 2, ('А', 'у'): 2, ('и', 'спросил'): 2, ('и', 'там'): 2, ('А', 'Яр'): 2, ('как', 'у'): 2, ('в', 'красных'): 2, ('Этого', 'не'): 2, ('Яр', 'Это'): 2, ('И', 'вдруг'): 2, ('похоже', 'на'): 2, ('висит', 'в'): 2, ('По', 'крайней'): 2, ('когда', 'крейсер'): 2, ('в', 'э ...

# %% [markdown]
# Мой ноутбук здесь отказался выдавать все нграммы без последующего падения, поэтому здесь представлен только кусочек, но в целом тенденция сохраняется: много всякого "X сказал", потому что в книге много диалогов. Ещё много комбинаций с отрицанием и союзами/предлогами.

# %%
ngram_list = []
for line in text_lines[:2000]:
    line_tokens = tokenizer.tokenize(line)
    n_grams = list(ngrams(line_tokens, 3))
    ngram_list.extend(n_grams)
print(collections.Counter(ngram_list))
# Out:
# Counter({('в', 'самом', 'деле'): 7, ('Ну', 'и', 'что'): 5, ('А', 'что', 'за'): 5, ('Игнатик', 'и', 'Алька'): 5, ('Раз', 'два', 'три'): 3, ('Вот', 'это', 'да'): 3, ('спросил', 'Яр', 'у'): 3, ('то', 'не', 'так'): 3, ('посмотрел', 'на', 'Яра'): 3, ('Яр', 'понял', 'что'): 3, ('Яра', 'за', 'руку'): 3, ('Яру', 'в', 'лицо'): 3, ('посмотрел', 'на', 'него'): 3, ('В', 'самом', 'деле'): 3, ('Тик', 'посмотрел', 'на'): 2, ('то', 'же', 'самое'): 2, ('отрываясь', 'от', 'книги'): 2, ('на', 'Данку', 'и'): 2, ('Яр', 'вспомнил', 'как'): 2, ('вспомнил', 'как', 'он'): 2, ('два', 'три', 'четыре'): 2, ('три', 'четыре', 'пять'): 2, ('Не', 'надо', 'про'): 2, ('на', 'спинку', 'скамьи'): 2, ('Чита', 'поднял', 'голову'): 2, ('Это', 'был', 'старый'): 2, ('Яр', 'у', 'Данки'): 2, ('не', 'было', 'И'): 2, ('сказал', 'Яр', 'Я'): 2, ('Яр', 'взглянул', 'на'): 2, ('взглянул', 'на', 'часы'): 2, ('Данка', 'и', 'Тик'): 2, ('был', 'какой', 'то'): 2, ('Но', 'тут', 'же'): 2, ('Яр', 'подумал', 'что'): 2, ('висит', 'в', 'субпространстве'): 2, ('По', 'крайней', 'мере'): 2, ('Ну', 'а', 'что'): 2, ('Яр', 'ничего', 'не'): 2, ('на', 'АЦ', '1'): 2, ('ноль', 'ноль', 'ноль'): 2, ('то', 'и', 'дело'): 2, ('А', 'может', 'быть'): 2, ('песчаных', 'кротов', 'на'): 2, ('кротов', 'на', 'АЦ'): 2, ('не', 'хотел', 'Но'): 2, ('Но', 'он', 'не'): 2, ('в', 'глазах', 'и'): 2, ('Все', 'равно', 'он'): 2, ('похожий', 'на', 'тот'): 2, ('с', 'усмешкой', 'подумал'): 2, ('Ну', 'что', 'ж'): 2, ('что', 'ж', 'подумал'): 2, ('подумал', 'Яр', 'и'): 2, ('Яр', 'не', 'знал'): 2, ('к', 'Яру', 'и'): 2, ('сказал', 'он', 'и'): 2, ('если', 'что', 'то'): 2, ('что', 'то', 'не'): 2, ('Совершенно', 'верно', 'сказал'): 2, ('верно', 'сказал', 'Яр'): 2, ('то', 'ли', 'с'): 2, ('до', 'сих', 'пор'): 2, ('А', 'в', 'самом'): 2, ('Я', 'не', 'обижаюсь'): 2, ('Игнатик', 'шагнул', 'к'): 2, ('шагнул', 'к', 'двери'): 2, ('В', 'конце', 'концов'): 2, ('звездами', 'на', 'рукаве'): 2, ('скромно', 'сказал', 'Игнатик'): 2, ('А', 'вы', 'не'): 2, ('вы', 'не', 'верили'): 2, ('взял', 'Яра', 'за'): 2, ('все', 'по', 'порядку'): 2, ('Игнатик', 'с', 'Алькой'): 2, ('Яр', 'Но', 'это'): 2, ('рядом', 'с', 'Читой'): 2, ('заглянул', 'Яру', 'в'): 2, ('сказал', 'Алька', 'и'): 2, ('Ты', 'все', 'равно'): 2, ('Данка', 'Впрочем', 'без'): 2, ('на', 'него', 'с'): 2, ('отозвался', 'Яр', 'Но'): 2, ('осторожно', 'сказал', 'Яр'): 2, ('Чита', 'пожал', 'плечами'): 2, ('сказал', 'Яр', 'Это'): 2, ('никто', 'и', 'не'): 2, ('нерешительно', 'спросила', 'Данка'): 2, ('И', 'все', 'же'): 2, ('все', 'же', 'Яр'): 2, ('Алька', 'и', 'Чита'): 2, ('Игнатика', 'и', 'Альку'): 2, ('и', 'в', 'самом'): 2, ('Игнатик', 'и', 'Чита'): 2, ('никто', 'не', 'знает'): 2, ('Никто', 'не', 'знает'): 2, ('Это', 'еще', 'в'): 2, ('Чита', 'посмотрел', 'на'): 2, ('Ничего', 'не', 'понимаю'): 2, ('в', 'прошлом', 'году'): 2, ('что', 'за', 'бормотунчик'): 2, ('у', 'края', 'очага'): 2, ('не', 'знаю', 'почему'): 2, ('и', 'сам', 'не'): 2, ('сам', 'не', 'знаю'): 2, ('в', 'пятую', 'лунку'): 2, ('через', 'край', 'сундука'): 2, ('хмуро', 'сказал', 'Чита'): 2, ('в', 'чрезвычайных', 'обстоятельствах'): 2, ('К', 'тому', 'же'): 2, ('ГОЛУБЯТНЯ', 'НА', 'ЖЕЛТОЙ'): 1, ('НА', 'ЖЕЛТОЙ', 'ПОЛЯНЕ'): 1, ('Книга', 'первая', 'ГОЛУБЯТНЯ'): 1, ('первая', 'ГОЛУБЯТНЯ', 'В'): 1, ('ГОЛУБЯТНЯ', 'В', 'ОРЕХОВЕ'): 1, ('Вступление', 'ОДИН', 'И'): 1, ('ОДИН', 'И', 'ЧЕТЫРЕ'): 1, ('Был', 'видимо', 'июнь'): 1, ('видимо', 'июнь', 'У'): 1, ('июнь', 'У', 'цирка'): 1, ('У', 'цирка', 'цвели'): 1, ('цирка', 'цвели', 'кусты'): 1, ('цвели', 'кусты', 'желтой'): 1, ('кусты', 'желтой', 'акации'): 1, ('желтой', 'акации', 'Алька'): 1, ('акации', 'Алька', 'не'): 1, ('Алька', 'не', 'вставая'): 1, ('со', 'скамьи', 'дотянулся'): 1, ('скамьи', 'дотянулся', 'до'): 1, ('дотянулся', 'до', 'ветки'): 1, ('до', 'ветки', 'сорвал'): 1, ('ветки', 'сорвал', 'похожий'): 1, ('сорвал', 'похожий', 'на'): 1, ('похожий', 'на', 'ушастого'): 1, ('на', 'ушастого', 'зверька'): 1, ('ушастого', 'зверька', 'цветок'): 1, ('сунул', 'в', 'рот'): 1, ('в', 'рот', 'Сладко'): 1, ('рот',  ...

# %% [markdown]
# Здесь скорее устойчивые выражения преобладают "в самом деле", "ну и что" и т.д. Но остальные в основном - сочетания с отрицанием и союзами/предлогами, как и в прошлый раз. (и смешное "раз два три")
